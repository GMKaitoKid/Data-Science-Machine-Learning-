# %%
import pandas as pd

# %%
colours = pd.Series(["red", "blue", "orange"])
colours
# Out:
# 0       red
# 1      blue
# 2    orange
# dtype: object

# %%
car_tyres = pd.Series(["Winter", "Summer", "All seasons"])
car_tyres
# Out:
# 0         Winter
# 1         Summer
# 2    All seasons
# dtype: object

# %%
car_data = pd.DataFrame({"Colour": colours, "Tyre types": car_tyres})
car_data
# Out:
#    Colour   Tyre types
# 0     red       Winter
# 1    blue       Summer
# 2  orange  All seasons

# %%
car_data.to_csv("Car-data.csv", index=False)

# %%
car_data.dtypes
# Out:
# Colour        object
# Tyre types    object
# dtype: object

# %%
car_data.describe()
# Out:
#        Colour Tyre types
# count       3          3
# unique      3          3
# top       red     Winter
# freq        1          1

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Colour      3 non-null      object
#  1   Tyre types  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %% [markdown]
#  As provided in the table, there are 3 distinct types of colours and tyre types of the car, each occuring only once throughout
#  the entire dataset. Each data is saved as an object.

# %%
numbers = pd.Series([2, 3, 5])
numbers
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
numbers.sum()
# Out:
# 10

# %%
numbers.mean()
# Out:
# 3.3333333333333335

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(5
              )
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
pd.crosstab(car_sales.Make, car_sales.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(car_sales["Odometer (KM)"])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <BarContainer object of 10 artists>)

# %%
car_sales(["Price"]).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 car_sales(["Price"]).plot()
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# Note that you can't plot any columns of a dataframe if the data type is not an integer. In this case, Price is an object.

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
# Remove the punctuation from price column
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "", regex=True)

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
# remove 2 extra zeros at the end of the price column
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
# change the data type to integer
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
make_lower = car_sales["Make"].str.lower()

# %%
make_lower
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = make_lower

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True
                                    )

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Create a new column called Seats
# Create a "Seats" column where every row has a value of 5
car_sales["Seats"] = 5
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Engine Size  Seats
# 0  toyota  White         150043      4   4000          1.3      5
# 1   honda    Red          87899      4   5000          4.3      5
# 2  toyota   Blue          32549      3   7000          2.3      5
# 3     bmw  Black          11179      5  22000          3.3      5
# 4  nissan  White         213095      4   3500          3.0      5
# 5  toyota  Green          99213      4   4500          2.3      5
# 6   honda   Blue          45698      4   7500          1.4      5
# 7   honda   Blue          54738      4   7000          1.7      5
# 8  toyota  White          60000      4   6250          2.5      5
# 9  nissan  White          31600      4   9700          3.1      5

# %%
engine_sizes = [1.3, 4.3, 2.3, 3.3, 3.0, 2.3, 1.4, 1.7, 2.5, 3.1]
car_sales["Engine Size"] = engine_sizes
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Engine Size
# 0  toyota  White         150043      4   4000          1.3
# 1   honda    Red          87899      4   5000          4.3
# 2  toyota   Blue          32549      3   7000          2.3
# 3     bmw  Black          11179      5  22000          3.3
# 4  nissan  White         213095      4   3500          3.0
# 5  toyota  Green          99213      4   4500          2.3
# 6   honda   Blue          45698      4   7500          1.4
# 7   honda   Blue          54738      4   7000          1.7
# 8  toyota  White          60000      4   6250          2.5
# 9  nissan  White          31600      4   9700          3.1

# %%
car_sales["Price per KM"] = car_sales["Price"]/car_sales["Odometer (KM)"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Engine Size  Seats  \
# 0  toyota  White         150043      4   4000          1.3      5
# 1   honda    Red          87899      4   5000          4.3      5
# 2  toyota   Blue          32549      3   7000          2.3      5
# 3     bmw  Black          11179      5  22000          3.3      5
# 4  nissan  White         213095      4   3500          3.0      5
# 5  toyota  Green          99213      4   4500          2.3      5
# 6   honda   Blue          45698      4   7500          1.4      5
# 7   honda   Blue          54738      4   7000          1.7      5
# 8  toyota  White          60000      4   6250          2.5      5
# 9  nissan  White          31600      4   9700          3.1      5
#
#    Price per KM
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962

# %%
# Remove the last column you added using .drop()
car_sales = car_sales.drop("Price per KM", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Engine Size  Seats
# 0  toyota  White         150043      4   4000          1.3      5
# 1   honda    Red          87899      4   5000          4.3      5
# 2  toyota   Blue          32549      3   7000          2.3      5
# 3     bmw  Black          11179      5  22000          3.3      5
# 4  nissan  White         213095      4   3500          3.0      5
# 5  toyota  Green          99213      4   4500          2.3      5
# 6   honda   Blue          45698      4   7500          1.4      5
# 7   honda   Blue          54738      4   7000          1.7      5
# 8  toyota  White          60000      4   6250          2.5      5
# 9  nissan  White          31600      4   9700          3.1      5

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Engine Size  Seats
# 3     bmw  Black          11179      5  22000          3.3      5
# 2  toyota   Blue          32549      3   7000          2.3      5
# 9  nissan  White          31600      4   9700          3.1      5
# 4  nissan  White         213095      4   3500          3.0      5
# 7   honda   Blue          54738      4   7000          1.7      5
# 6   honda   Blue          45698      4   7500          1.4      5
# 5  toyota  Green          99213      4   4500          2.3      5
# 0  toyota  White         150043      4   4000          1.3      5
# 1   honda    Red          87899      4   5000          4.3      5
# 8  toyota  White          60000      4   6250          2.5      5

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_shuffled.reset_index(drop=False, inplace=True)
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Engine Size  Seats
# 0      3     bmw  Black          11179      5  22000          3.3      5
# 1      2  toyota   Blue          32549      3   7000          2.3      5
# 2      9  nissan  White          31600      4   9700          3.1      5
# 3      4  nissan  White         213095      4   3500          3.0      5
# 4      7   honda   Blue          54738      4   7000          1.7      5
# 5      6   honda   Blue          45698      4   7500          1.4      5
# 6      5  toyota  Green          99213      4   4500          2.3      5
# 7      0  toyota  White         150043      4   4000          1.3      5
# 8      1   honda    Red          87899      4   5000          4.3      5
# 9      8  toyota  White          60000      4   6250          2.5      5

# %%
car_sales
# Out:
#      Make Colour  Doors  Price  Engine Size  Seats  Odometer (Miles)  \
# 0  toyota  White      4   4000          1.3      5         93776.875
# 1   honda    Red      4   5000          4.3      5         54936.875
# 2  toyota   Blue      3   7000          2.3      5         20343.125
# 3     bmw  Black      5  22000          3.3      5          6986.875
# 4  nissan  White      4   3500          3.0      5        133184.375
# 5  toyota  Green      4   4500          2.3      5         62008.125
# 6   honda   Blue      4   7500          1.4      5         28561.250
# 7   honda   Blue      4   7000          1.7      5         34211.250
# 8  toyota  White      4   6250          2.5      5         37500.000
# 9  nissan  White      4   9700          3.1      5         19750.000
#
#    Odometer (MILES)
# 0      58610.546875
# 1      34335.546875
# 2      12714.453125
# 3       4366.796875
# 4      83240.234375
# 5      38755.078125
# 6      17850.781250
# 7      21382.031250
# ...

# %%
car_sales = car_sales.drop("Odometer (MILES)", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Doors  Price  Engine Size  Seats  Odometer (Miles)
# 0  toyota  White      4   4000          1.3      5         93776.875
# 1   honda    Red      4   5000          4.3      5         54936.875
# 2  toyota   Blue      3   7000          2.3      5         20343.125
# 3     bmw  Black      5  22000          3.3      5          6986.875
# 4  nissan  White      4   3500          3.0      5        133184.375
# 5  toyota  Green      4   4500          2.3      5         62008.125
# 6   honda   Blue      4   7500          1.4      5         28561.250
# 7   honda   Blue      4   7000          1.7      5         34211.250
# 8  toyota  White      4   6250          2.5      5         37500.000
# 9  nissan  White      4   9700          3.1      5         19750.000
